# %%
# Activity 1: Descriptive Statistical Analysis

import pandas as pd

# Load the cleaned dataset
df = pd.read_csv('../data//liver_dataset_cleaned.csv')  # Adjust path as needed

# Preview first few rows
df.head()
# Out:
#         Age    Gender  Total_Bilirubin  Direct_Bilirubin  \
# 0  1.247403 -1.770795        -0.420320         -0.495414
# 1  1.062306  0.564718         1.218936          1.423518
# 2  1.062306  0.564718         0.640375          0.926017
# 3  0.815511  0.564718        -0.372106         -0.388807
# 4  1.679294  0.564718         0.093956          0.179766
#
#    Alkaline_Phosphotase  Alamine_Aminotransferase  Aspartate_Aminotransferase  \
# 0             -0.428870                 -0.355832                   -0.319111
# 1              1.675083                 -0.093573                   -0.035962
# 2              0.816243                 -0.115428                   -0.146459
# 3             -0.449416                 -0.366760                   -0.312205
# 4             -0.395996                 -0.295731                   -0.177537
#
#    Total_Protiens   Albumin  Albumin_and_Globulin_Ratio  Target
# 0        0.293722  0.203446                   -0.147390       1
# ...

# %%
# Check basic structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         579 non-null    float64
#  1   Gender                      579 non-null    float64
#  2   Total_Bilirubin             579 non-null    float64
#  3   Direct_Bilirubin            579 non-null    float64
#  4   Alkaline_Phosphotase        579 non-null    float64
#  5   Alamine_Aminotransferase    579 non-null    float64
#  6   Aspartate_Aminotransferase  579 non-null    float64
#  7   Total_Protiens              579 non-null    float64
#  8   Albumin                     579 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Target                      579 non-null    int64
# dtypes: float64(10), int64(1)
# memory usage: 49.9 KB

# %%
# Descriptive statistics
df.describe()
# Out:
#                 Age        Gender  Total_Bilirubin  Direct_Bilirubin  \
# count  5.790000e+02  5.790000e+02     5.790000e+02      5.790000e+02
# mean   6.442745e-17  4.908758e-17     5.215555e-17      3.067974e-17
# std    1.000865e+00  1.000865e+00     1.000865e+00      1.000865e+00
# min   -2.516224e+00 -1.770795e+00    -4.685332e-01     -4.954142e-01
# 25%   -7.269589e-01  5.647182e-01    -4.042487e-01     -4.598784e-01
# 50%    1.342668e-02  5.647182e-01    -3.721064e-01     -4.243426e-01
# 75%    8.155111e-01  5.647182e-01    -1.149683e-01     -6.898483e-02
# max    2.789873e+00  5.647182e-01     1.152053e+01      6.469598e+00
#
#        Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count          5.790000e+02              5.790000e+02
# mean           1.227190e-17              4.908758e-17
# std            1.000865e+00              1.000865e+00
# min           -9.384212e-01             -3.886149e-01
# 25%           -4.761268e-01             -3.175862e-01
# ...

# %%
# Check distribution of the target
df['Target'].value_counts()
# Out:
# Target
# 1    414
# 0    165
# Name: count, dtype: int64

# %%
# Check distribution of the target
df['Target'].value_counts()
# Out:
# Target
# 1    414
# 0    165
# Name: count, dtype: int64

# %%
# Check for skewness (optional)
df.skew()
# Out:
# Age                           -0.033591
# Gender                        -1.209212
# Total_Bilirubin                4.890768
# Direct_Bilirubin               3.199163
# Alkaline_Phosphotase           3.753502
# Alamine_Aminotransferase       6.527575
# Aspartate_Aminotransferase    10.512251
# Total_Protiens                -0.292433
# Albumin                       -0.048516
# Albumin_and_Globulin_Ratio     0.992299
# Target                        -0.955179
# dtype: float64

# %%
# Correlation between features
correlation_matrix = df.corr()
correlation_matrix['Target'].sort_values(ascending=False)
# Out:
# Target                        1.000000
# Direct_Bilirubin              0.246273
# Total_Bilirubin               0.220218
# Alkaline_Phosphotase          0.183363
# Alamine_Aminotransferase      0.163117
# Aspartate_Aminotransferase    0.151834
# Age                           0.133164
# Gender                        0.081349
# Total_Protiens               -0.033614
# Albumin                      -0.159770
# Albumin_and_Globulin_Ratio   -0.163131
# Name: Target, dtype: float64
